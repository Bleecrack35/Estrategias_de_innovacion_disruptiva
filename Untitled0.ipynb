# %% [markdown]
# #Introducción a la Innovación Disruptiva
#
# ##Creación de bases de datos
#
# ![Image](https://media3.giphy.com/media/v1.Y2lkPTc5MGI3NjExZDZpOXFjYXU0NXA3NXJndmR1NnhhY3R5bWlqdjhsbzg0bTZhdDF6aCZlcD12MV9pbnRlcm5hbF9naWZfYnlfaWQmY3Q9Zw/4Op3t0ZggRlZeirX0Z/giphy.gif)

# %%
Top_startups =[
  {
    "rank": 1,
    "name": "Perplexity AI",
    "sector": "AI-powered search",
    "founding_year": 2022,
    "description": "Generative AI conversational search engine answering user queries directly",
    "notable_metrics": {
      "monthly_active_users": "10 million",
      "valuation": "approx $2.5–3 billion",
      "funding": "Series B / C"
    }
  },
  {
    "rank": 2,
    "name": "Scale AI",
    "sector": "AI training data",
    "description": "High‑quality labelled training datasets for machine learning",
    "notable_metrics": {
      "latest_round": "Series F",
      "valuation": "≈ $13.8 billion"
    }
  },
  {
    "rank": 3,
    "name": "Vytalize Health",
    "sector": "healthcare technology",
    "description": "Primary care delivery via value‑based care model",
    "notable_metrics": {
      "three_year_rev_growth": "≈ 90,779 %",
      "ranking": "Inc. 5000 #1"
    }
  },
  {
    "rank": 4,
    "name": "Codeium",
    "sector": "AI developer tools",
    "description": "AI‑powered coding assistant improving developer productivity",
    "notable_metrics": {
      "funding": "Series C",
      "valuation": "≈ $1.25 billion"
    }
  },
  {
    "rank": 5,
    "name": "CIRCA5000",
    "sector": "fintech / social impact",
    "description": "Platform connecting investors with values‑aligned, cause‑focused companies",
    "notable_metrics": {}
  },
  {
    "rank": 6,
    "name": "Goodr",
    "sector": "food waste / social enterprise",
    "description": "Manages food surplus to reduce waste and feed underserved communities",
    "notable_metrics": {}
  },
  {
    "rank": 7,
    "name": "Charm Industrial",
    "sector": "climate / carbon removal",
    "description": "Converts biomass into stable carbon‑rich liquids for underground sequestration",
    "notable_metrics": {}
  },
  {
    "rank": 8,
    "name": "Liquid Death",
    "sector": "consumer packaged goods",
    "description": "Marketing‑driven canned water brand turned cultural phenomenon",
    "notable_metrics": {
      "revenue_2023": "$263 million",
      "valuation": "≈ $1.4 billion"
    }
  },
  {
    "rank": 9,
    "name": "Watershed",
    "sector": "enterprise climate software",
    "description": "Platform helping companies measure, report and reduce carbon emissions",
    "notable_metrics": {}
  },
  {
    "rank": 10,
    "name": "FreeWater",
    "sector": "social impact / consumer product",
    "description": "Offers free drinking water funded by ad revenue and builds wells in Africa",
    "notable_metrics": {}
  }
]

# %%
EID_701 = {"Rodrigo":[21, "soltero", "Valeria",1.70],"Sam":[21, "soltera","Blee",1.67],"Luis":[20, "soltero", "Angie", 1.65]}

# %%
EID_701.keys()
# Out:
# dict_keys(['Rodrigo', 'Sam', 'Luis'])

# %%
EID_701.values()
# Out:
# dict_values([[21, 'soltero', 'Valeria', 1.7], [21, 'soltera', 'Blee', 1.67], [20, 'soltero', 'Angie', 1.65]])

# %%
import pandas as pd

DF_701 = pd.DataFrame(EID_701,index=["edad","estado civil","pareja","altura"])

# %%
DF_701
# Out:
#               Rodrigo      Sam     Luis
# edad               21       21       20
# estado civil  soltero  soltera  soltero
# pareja        Valeria     Blee    Angie
# altura            1.7     1.67     1.65

# %%
# ¿Cuáles son los datos de Sam?
DF_701["Sam"]
# Out:
# edad                 21
# estado civil    soltera
# pareja             Blee
# altura             1.67
# Name: Sam, dtype: object

# %%
# ¿Cuáles es la edad de Sam?
DF_701["Sam"][0]
# Out:
# /tmp/ipython-input-194208678.py:2: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   DF_701["Sam"][0]
# 21

# %%
import pandas as pd

pd.DataFrame(Top_startups)
# Out:
#    rank              name                            sector  founding_year  \
# 0     1     Perplexity AI                 AI-powered search         2022.0
# 1     2          Scale AI                  AI training data            NaN
# 2     3   Vytalize Health             healthcare technology            NaN
# 3     4           Codeium                AI developer tools            NaN
# 4     5         CIRCA5000           fintech / social impact            NaN
# 5     6             Goodr    food waste / social enterprise            NaN
# 6     7  Charm Industrial          climate / carbon removal            NaN
# 7     8      Liquid Death           consumer packaged goods            NaN
# 8     9         Watershed       enterprise climate software            NaN
# 9    10         FreeWater  social impact / consumer product            NaN
#
#                                          description  \
# 0  Generative AI conversational search engine ans...
# 1  High‑quality labelled training datasets for ma...
# 2   Primary care delivery via value‑based care model
# 3  AI‑powered coding assistant improving develope...
# 4  Platform connecting investors with values‑alig...
# 5  Manages food surplus to reduce waste and feed ...
# 6  Converts biomass into stable carbon‑rich liqui...
# 7  Marketing‑driven canned water brand turned cul...
# 8  Platform helping companies measure, report and...
# 9  Offers free drinking water funded by ad revenu...
#
#                                      notable_metrics
# 0  {'monthly_active_users': '10 million', 'valuat...
# 1  {'latest_round': 'Series F', 'valuation': '≈ $...
# 2  {'three_year_rev_growth': '≈ 90,779 %', 'ranki...
# 3  {'funding': 'Series C', 'valuation': '≈ $1.25 ...
# 4                                                 {}
# 5                                                 {}
# 6                                                 {}
# 7  {'revenue_2023': '$263 million', 'valuation': ...
# 8                                                 {}
# 9                                                 {}

# %% [markdown]
# Bases de datos

# %%
estudiantes = {"Sam":[3, 4, 5, 8, 3.3],
               "Angel" : [-1.5, 0 , 2, 5, 10],
               "Rangel" : [7.7, 8.0, 8.2, 9, 9],
               "Zarate" : [0, 10, 8, 3.5, 0],
               "Ricardo": [3, 6.2, 7, 2, 8]}

# %%
estudiantes
# Out:
# {'Sam': [3, 4, 5, 8, 3.3],
#  'Angel': [-1.5, 0, 2, 5, 10],
#  'Rangel': [7.7, 8.0, 8.2, 9, 9],
#  'Zarate': [0, 10, 8, 3.5, 0],
#  'Ricardo': [3, 6.2, 7, 2, 8]}

# %%
import pandas as pd

tablita = pd.DataFrame(estudiantes)
tablita
# Out:
#    Sam  Angel  Rangel  Zarate  Ricardo
# 0  3.0   -1.5     7.7     0.0      3.0
# 1  4.0    0.0     8.0    10.0      6.2
# 2  5.0    2.0     8.2     8.0      7.0
# 3  8.0    5.0     9.0     3.5      2.0
# 4  3.3   10.0     9.0     0.0      8.0

# %%
tablita.describe()
# Out:
#             Sam      Angel    Rangel     Zarate   Ricardo
# count  5.000000   5.000000  5.000000   5.000000  5.000000
# mean   4.660000   3.100000  8.380000   4.300000  5.240000
# std    2.019406   4.560702  0.593296   4.577117  2.605379
# min    3.000000  -1.500000  7.700000   0.000000  2.000000
# 25%    3.300000   0.000000  8.000000   0.000000  3.000000
# 50%    4.000000   2.000000  8.200000   3.500000  6.200000
# 75%    5.000000   5.000000  9.000000   8.000000  7.000000
# max    8.000000  10.000000  9.000000  10.000000  8.000000
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Sam'].plot(kind='hist', bins=20, title='Sam')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Angel'].plot(kind='hist', bins=20, title='Angel')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Rangel'].plot(kind='hist', bins=20, title='Rangel')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Zarate'].plot(kind='hist', bins=20, title='Zarate')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='Sam', y='Angel', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Angel', y='Rangel', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Rangel', y='Zarate', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Zarate', y='Ricardo', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_8['Sam'].plot(kind='line', figsize=(8, 4), title='Sam')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_9['Angel'].plot(kind='line', figsize=(8, 4), title='Angel')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_10['Rangel'].plot(kind='line', figsize=(8, 4), title='Rangel')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_11['Zarate'].plot(kind='line', figsize=(8, 4), title='Zarate')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
tablita.describe()
# Out:
#             Sam      Angel    Rangel     Zarate   Ricardo
# count  5.000000   5.000000  5.000000   5.000000  5.000000
# mean   4.660000   3.100000  8.380000   4.300000  5.240000
# std    2.019406   4.560702  0.593296   4.577117  2.605379
# min    3.000000  -1.500000  7.700000   0.000000  2.000000
# 25%    3.300000   0.000000  8.000000   0.000000  3.000000
# 50%    4.000000   2.000000  8.200000   3.500000  6.200000
# 75%    5.000000   5.000000  9.000000   8.000000  7.000000
# max    8.000000  10.000000  9.000000  10.000000  8.000000

# %%
import seaborn as sns

sns.boxplot(data=tablita)
# Out:
# <Axes: >
